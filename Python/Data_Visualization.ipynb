# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Table of Contents
# ># 1. Matplotlib - Simple Plot
# * 1.1. Line Plot
# * 1.2. Customize Style
# * 1.3. Customize Range / Ticks / Tick Lables / Grid
# * 1.4. Legend
# * 1.5. Axis Labels & Plot Title
# * 1.6. Multiple Plots
#
# ># 2. Matplotlib - Figure Object
# * 2.1. Figure Object
# * 2.2. Axes Object & `subplot` Command
# * 2.3. Axis Object
#
# ># 3. Matplotlib - Various Charts & Plots
# * 3.1. Bar Chart
# * 3.2. Stem Chart
# * 3.3. Pie Chart
# * 3.4. Histogram
# * 3.5. Scatter Plot
# * 3.6. Bubble Chart
# * 3.7. Imshow
# * 3.8. Contour Plot
# * 3.9. 3D Surface Plot
#
# ># 4. Matplotlib - Triangular Grid
# * 4.1. Classes
# * 4.2. Generate
# * 4.3. Refine
# * 4.4. Contour Plot
# * 4.5. Surface Plot
#
# ># 5. Seaborn
# * 5.1. Style
# * 5.2. 1D Distribution
# * 5.3. 2D Real Values $\rightarrow$ Scatter Plot
# * 5.4. 2+D Real Values $\rightarrow$ Pairplot
# * 5.5. 2D Categorical Values $\rightarrow$ Heatmap
# * 5.6. 2D Mixed Data
# * 5.7. 2+D Mixed Data
#
# ># 6. Visualization with `Pandas`
# * 6.1. `plot` Command
# * 6.2. Set `kind` Parameter
# * 6.3. `plot.bar` Command
# * 6.4. `boxplot`

# %% [markdown]
# # 1. Matplotlib - Simpe Plot

# %%
#allow matplotlib to plot directly on notebook
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pylab as plt

# %% [markdown]
# ## 1.1. Line Plot
# * `plt.plot(list or ndarray)`
# * [more info](http://Matplotlib.org/api/pyplot_api.html#Matplotlib.pyplot.plot)

# %%
plt.plot([1, 4, 9, 16]) #only y values are specified
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16]) #x & y values are specified
plt.show()

# %% [markdown]
# ## 1.2. Customize Style
# * Style string: **color + marker + line style**
# * **color**
#   * RGB or RGBA tuple of float values in [0, 1]
#   * hex RGB or RGBA tuple of float values in [0, 1]
#   * string representation of a float value in [0, 1] $\rightarrow$ gray level
#   * one of {**'b'**lue, **'g'**reen, **'r'**ed, **'c'**yan, **'m'**agenta, **'y'**ellow, blac**'k'**, **'w'**hite};
#
# * **marker**
#
# | string | marker |
# |-|-|
# | `.` | point marker  |
# | `,` | pixel marker |
# | `o` | circle marker |
# | `v` | triangle_down marker |
# | `^` | triangle_up marker |
# | `<` | triangle_left marker |
# | `>` | triangle_right marker |
# | `1` | tri_down marker |
# | `2` | tri_up marker |
# | `3` | tri_left marker |
# | `4` | tri_right marker |
# | `s` | square marker |
# | `p` | pentagon marker |
# | `*` | star marker |
# | `h` | hexagon1 marker |
# | `H` | hexagon2 marker |
# | `+` | plus marker |
# | `x` | x marker |
# | `D` | diamond marker |
# | `d` | thin_diamond marker |
#
# * **line style**
#
# | string | line style |
# |-|-|
# | `-` |  solid line style
# | `--` |  dashed line style
# | `-.` |  dash-dot line style
# | `:` |  dotted line style
#
# * **to add more style, specify style parameters**
#
# | parameter | style |
# |-|-|
# | `c`  | `color` |
# | `lw` | `linewidth` |
# | `ls` | `linestyle` |
# | `marker` | `marker` |
# | `ms` | `markersize` |
# | `mec` | `markeredgecolor` |
# | `mew` | `markeredgewidth` |
# | `mfc` | `markerfacecolor` |

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b", 
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.show()

# %% [markdown]
# ## 1.3. Customize Range / Ticks / Tick Lables / Grid

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")

# Range
plt.xlim(0, 50)
plt.ylim(-10, 30)

# Ticks
plt.xticks([10, 20, 30, 40])

# Tick Labels
plt.yticks([0, 10, 20], ["Low", "Zero", "High"])

# Grid
plt.grid(True)


plt.show()

# %% [markdown]
# ## 1.4. Legend
# * `loc` parameter: specifies the location of the legend
#
# | loc | location |
# | - |-|
# | 0 | `best` |
# | 1 | `upper right` |
# | 2 | `upper left` |
# | 3 | `lower left` |
# | 4 | `lower right` |
# | 5 | `right` |
# | 6 | `center left` |
# | 7 | `center right` |
# | 8 | `lower center` |
# | 9 | `upper center` |
# | 10 | `center` |

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## 1.5. Axis Labels & Plot Title

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %% [markdown]
# ## 1.6. Multiple Plots
# * Single `plot` command
#   * `plt.plot(x1, y1, style1, x2, y2, style2, ...)`
#   * In this case, x data & style string cannot be omitted
# * Multiple `plot` command
#   * use `plt.hold(True)` for Matplotlib 1.5 or less

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# or equivalently
plt.plot(t, t, 'r--')
plt.plot(t, 0.5 * t**2, 'bs:')
plt.plot(t, 0.2 * t**3, 'g^-')
plt.show()

# %% [markdown]
# # 2. Matplotlib - Figure Object
# * `Figure` Object > 1+ `Axes` Object > 1+ `Axis` Object
#
# <img src="https://datascienceschool.net/upfiles/4e20efe6352e4f4fac65c26cb660f522.png" style="width: 50%">

# %% [markdown]
# ## 2.1. Figure Object
# * Each `Figure` object has an ID No. & a Window
#   * In Notebook, the window object is not generated
# * `Figure` object is automatically generated when using `plot` command

# %% [markdown]
# ### `figure` command

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2))
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# ### `gcf` command

# %%
f1 = plt.figure(1)
plt.plot([1, 2, 3, 4], 'ro:')
f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(2400x1500) 139679867290232
# Figure(2400x1500) 139679867290232

# %% [markdown]
# ## 2.2. Axes Object & `subplot` Command
# * Use `tight_layout` to automatically adjust the gap between the plots
# * Example
# ```
# subplot(2, 1, 1)
# # commands for upper plot
# subplot(2, 1, 2)
# # commands for lower plot
# ```
# * OR equivalently
# ```
# subplot(211)
# # commands for upper plot
# subplot(212)
# # commands for lower plot
# ```

# %% [markdown]
# ### Example 1 - Two Plots

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %% [markdown]
# ### Example 2 - Four Plots

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Example 3 - generate multiple `Axes` objects using `subplots` command

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.3. Axis Object
# * Use `twinx` command to generate a new `Axes` object with shared `x axis`

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()

ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)

plt.show()

# %% [markdown]
# # 3. Matplotlib - Various Charts & Plots

# %% [markdown]
# ## 3.1. Bar Chart
# * `bar`: bar chart
# * `barh`: horizontal bar chart
# * **parameters**
#   * `xerr` & `yerr`: add error bar
#   * `alpha`: transparency

# %%
y = [2, 3, 1]
x = [0, 1, 2]
xlabel = ['A', 'B', 'C']
error = np.random.rand(3)

plt.bar(x, y, yerr=error, alpha=0.5)
plt.xticks(x, xlabel)
plt.show()

# %% [markdown]
# ## 3.2. Stem Plot
# * Bar chart w/o width

# %%
x = np.linspace(0.1, 2 * np.pi, 10)
plt.stem(x, np.cos(x), '-.')
plt.show()

# %% [markdown]
# ## 3.3. Pie Chart
# * `plt.axis('equal')` to make it circle

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## 3.4. Histogram
# * `bins` parameter: no. of bins

# %%
np.random.seed(0)
x = np.random.randn(1000)

arrays, bins, patches = plt.hist(x, bins=10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %%
patches
# Out:
# <a list of 10 Patch objects>

# %% [markdown]
# ## 3.5. Scatter Plot

# %%
np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)

plt.scatter(X, Y)
plt.show()

# %% [markdown]
# ## 3.6. Bubble Chart
# * Used for 3D & 4D data
# * `s`: size
# * `c`: color

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)

y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2

plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %% [markdown]
# ## 3.7. Imshow
# * 2D data with rows & columns $\rightarrow$ 2D image

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.show()

# %% [markdown]
# ## 3.8. Contour Plot
# * 3D data $\rightarrow$ x, y, height
# * `contour`: contour only
# * `contourf`: contour + color
#   * `meshgrid` generates grid point matrix

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 -y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

# %%
plt.contourf(XX, YY, ZZ, alpha=.75, cmap='jet')
plt.contour(XX, YY, ZZ, colors='black')
plt.show()

# %% [markdown]
# ## 3.9. 3D Surface Plot

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)

XX, YY = np.meshgrid(X, Y)

RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(XX, YY, ZZ, rstride=1, cstride=1, cmap='hot')
plt.show()

# %% [markdown]
# # 4. Matplotlib - Traingular Grid

# %%
import matplotlib.tri as mtri

# %% [markdown]
# ## 4.1. Classes
#
# * Generate
#   * `Triangulation` [more](http://matplotlib.org/api/tri_api.html?highlight=triangulation#matplotlib.tri.Triangulation)
#
# * Refine
#   * `TriRefiner` [more](http://matplotlib.org/api/tri_api.html?highlight=triangulation#matplotlib.tri.TriRefiner)
#   * `UniformTriRefiner` [more](http://matplotlib.org/api/tri_api.html?highlight=triangulation#matplotlib.tri.UniformTriRefiner)
#
# * Triangular Grid Plot
#   * `triplot` [more](http://matplotlib.org/api/pyplot_api.html?#matplotlib.pyplot.triplot)
#   * `tricontour` [more](http://matplotlib.org/api/pyplot_api.html?#matplotlib.pyplot.tricontour)
#   * `tricontourf` [more](http://matplotlib.org/api/pyplot_api.html?#matplotlib.pyplot.tricontourf)
#   * `tripcolor` [more](http://matplotlib.org/api/pyplot_api.html?#matplotlib.pyplot.tripcolor)
#
# * Triangular Grid Interpolation
#   * `TriInterpolator` [more](http://matplotlib.org/api/tri_api.html?highlight=triangulation#matplotlib.tri.TriInterpolator)
#   * `LinearTriInterpolator` [more](http://matplotlib.org/api/tri_api.html?highlight=triangulation#matplotlib.tri.LinearTriInterpolator)
#   * `CubicTriInterpolator` [more](http://matplotlib.org/api/tri_api.html?highlight=triangulation#matplotlib.tri.CubicTriInterpolator)

# %% [markdown]
# ## 4.2. Generate

# %%
x = np.asarray([0, 1, 2])
y = np.asarray([0, np.sqrt(3), 0])
triangles = [[0, 1, 2]]
triang = mtri.Triangulation(x, y, triangles)
plt.triplot(triang, 'ko-')
plt.xlim(-0.1, 2.1)
plt.ylim(-0.1, 1.8)
plt.show()

# %%
x = np.asarray([0, 1, 2, 3, 4, 2])
y = np.asarray([0, np.sqrt(3), 0, np.sqrt(3), 0, 2*np.sqrt(3)])
triangles = [[0, 1, 2], [2, 3, 4], [1, 2, 3], [1, 3, 5]]
triang = mtri.Triangulation(x, y, triangles)
plt.triplot(triang, 'ko-')
plt.xlim(-0.1, 4.1)
plt.ylim(-0.1, 3.7)
plt.show()

# %% [markdown]
# ## 4.3. Refine
# * `TriRefiner` & `UniformTriRefiner` class
#   * `refine_triangulation`: simple refine
#   * `refine_field`: optimized refine

# %%
refiner = mtri.UniformTriRefiner(triang)
triang2 = refiner.refine_triangulation(subdiv=2)
plt.triplot(triang2, 'ko-')
plt.xlim(-0.1, 4.1)
plt.ylim(-0.1, 3.7)
plt.show()

# %% [markdown]
# ## 4.4. Contour Plot
# * `tricontour` or `tricontourf` command

# %%
triang5 = refiner.refine_triangulation(subdiv=5)
z5 = np.cos(1.5*triang5.x)*np.cos(1.5*triang5.y)
plt.tricontourf(triang5, z5)
plt.show()

# %% [markdown]
# ## 4.5. Surface Plot
# * `plot_trisur` or `plot_trisurf` command

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

triang3 = refiner.refine_triangulation(subdiv=3)
z3 = np.cos(1.5 * triang3.x) * np.cos(1.5 * triang3.y)

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(triang3.x, triang3.y, z3, cmap=cm.jet, linewidth=0.2)
ax.tricontourf(triang3, z3, zdir='z', offset=-1.2, cmap=cm.coolwarm)
ax.set_zlim(-1, 1)
ax.view_init(40, -40)
plt.show()

# %% [markdown]
# # 5. Seaborn

# %% [markdown]
# ## 5.1. Style
# `set`: set Seaborn default style
# `set_style`: set **tick** style (`darkgrid`, `whitegrid`, `dark`, `white`, `ticks`)
# `set_color_codes`: change how matplotlib color shorthands are interpreted

# %%
import seaborn as sns
sns.set()
sns.set_style('whitegrid')
sns.set_color_codes()

# %% [markdown]
# ### Color Palette

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.color_palette("Blues"))

# %%
sns.palplot(sns.dark_palette("muted purple", input="xkcd"))

# %% [markdown]
# ## 5.2. 1D Distribution
# * Real values $\rightarrow$ histogram
# * Categorical $\rightarrow$ count plot

# %% [markdown]
# ### Histogram
# * `rugplot`: express data points as small lines
# * `kdeplot`: express distribution with a smooth curve
# * `distplot`: rug + kernel density

# %%
iris = sns.load_dataset("iris")

x = iris.petal_length.values

sns.rugplot(x)

plt.show()

# %%
sns.kdeplot(x)
plt.show()

# %%
sns.distplot(x, kde=True, rug=True)
plt.show()

# %% [markdown]
# ### Count Plot
# * `countplot(x="column_name", data=dataframe)`

# %%
titanic = sns.load_dataset("titanic")

sns.countplot(x="class", data=titanic)

plt.show()

# %% [markdown]
# ## 5.3. 2D Real Values $\rightarrow$ Scatter Plot
# * `jointplot(x="x_name", y="y_name", data=dataframe, kind='scatter')`
# * `kind='kde'` $\rightarrow$ kernel density histogram

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris)
plt.show()

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris, kind="kde")
plt.show()

# %% [markdown]
# ## 5.4. 2+D Real Values $\rightarrow$ Pairplot
# * `pairplot(dataframe)`
# * categorical labels $\rightarrow$ set `hue` parameter

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
plt.show()

# %% [markdown]
# ## 5.5. 2D Categorical Values $\rightarrow$ Heatmap

# %%
titanic = sns.load_dataset("titanic")

titanic_size = titanic.pivot_table(index="class", columns="sex", aggfunc="size")

titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size, cmap=sns.light_palette("gray", as_cmap=True), annot=True, fmt="d")
plt.show()

# %% [markdown]
# ## 5.6. 2D Mixed Data

# %% [markdown]
# 만약 데이터가 2차원이고 실수 값, 카테고리 값이 섞여 있다면 기존의 플롯 이외에도 다음과 같은 분포 플롯들을 이용할 수 있다.
#
# * `barplot`
# * `boxplot`
# * `pointplot`
# * `violinplot`
# * `stripplot`
# * `swarmplot`

# %% [markdown]
# ### `barplot`
# * Real values (with error bar) vs. Categorical values

# %%
tips = sns.load_dataset("tips")

sns.barplot(x="day", y="total_bill", data=tips)

plt.show()

# %% [markdown]
# ### `boxplot`
# * Box-Whisker Plot
#
# |||
# |-|-|
# | **Box** | Q1 & Q3|
# | **IQR(interquartile range)** | Q3 - Q1 |
# | **Line inside Box** | median |
# | **Vertical Line** | line between the min & max points in (Q1 - 1.5 * IQR, Q3 + 1.5 * IQR) |
# | **Dots** | outliers |

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# ### `violinplot`

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# ### `stripplot`
# * set `jitter=True` to avoid overlap by randomly shifting the data horizontally

# %%
np.random.seed(0)
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
plt.show()

# %% [markdown]
# ### `swarmplot`
# * Similar to `stripplot`, but data points are shifted to avoid overlap

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# ## 5.7. 2+D Mixed Data
# ### set `hue` parameter

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips)
plt.show()

# %%
np.random.seed(0)
sns.stripplot(x="day", y="total_bill", hue="sex", data=tips, jitter=True)
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)
plt.show()

# %% [markdown]
# ### Use `split` or `dodge`

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True)
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", hue="sex", data=tips, jitter=True, dodge=True)
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips, dodge=True)
plt.show()

# %% [markdown]
# ### Use `heatmap`

# %%
flights = sns.load_dataset("flights")

flights_passengers = flights.pivot("month", "year", "passengers")

sns.heatmap(flights_passengers, annot=True, fmt="d", linewidths=1)

plt.show()

# %% [markdown]
# ### Use `factorplot`
# * Use `hue` & `row`

# %%
data = titanic[titanic.survived.notnull()]
sns.factorplot(x="age", y="sex", hue="survived", row="class", data=data,
               kind="violin", split=True, size=2, aspect=4)
plt.show()

# %% [markdown]
# ### Overlap 1+ Charts

# %%
sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
sns.stripplot(x="tip", y="day", data=tips, jitter=True, color="0.4")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="0.9")
plt.show()

# %% [markdown]
# # 6. Visualization with `Pandas`
# * `Pandas` uses `matplotlib` internally

# %% [markdown]
# ## 6.1. `plot` Command

# %%
np.random.seed(0)
df1 = pd.DataFrame(np.random.randn(100, 3), 
                  index=pd.date_range('1/1/2018', periods=100), 
                  columns=['A', 'B', 'C']).cumsum()
df1.tail()
# Out:
#                     A          B          C
# 2018-04-06   9.396256   6.282026 -11.198087
# 2018-04-07  10.086074   7.583872 -11.826175
# 2018-04-08   9.605047   9.887789 -12.886190
# 2018-04-09   9.469097  11.024680 -12.788465
# 2018-04-10  10.052051  10.625231 -12.418409

# %%
df1.plot()
plt.show()

# %% [markdown]
# ## 6.2. Set `kind` Parameter
# * `bar`
# * `pie`
# * `hist`
# * `kde`
# * `box`
# * `scatter`
# * `area`

# %%
iris = sns.load_dataset("iris")    
titanic = sns.load_dataset("titanic")

# %%
iris.sepal_length[:20].plot(kind='bar', rot=0)
plt.show()

# %% [markdown]
# ## 6.3. `plot.bar` Command

# %%
df2 = iris.groupby(iris.species).mean()
df2.columns.name = "feature"
df2
# Out:
# feature     sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df2.plot.bar(rot=0)
plt.ylim(0, 8)
plt.show()

# %%
df3 = titanic.pclass.value_counts()
df3.plot.pie(autopct='%.2f%%')
plt.axis('equal')
plt.show()

# %%
iris.plot.hist()
plt.show()

# %%
iris.plot.kde()
plt.show()

# %%
iris.plot.box()
plt.show()

# %%
iris.plot.scatter(x='sepal_length', y='sepal_width')
plt.show()

# %% [markdown]
# ## 6.4. `boxplot`

# %%
iris.boxplot(by='species')
plt.tight_layout(pad=3, h_pad=1)
plt.show()
